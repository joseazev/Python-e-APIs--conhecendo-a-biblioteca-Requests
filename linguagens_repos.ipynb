# %% [markdown]
# # conecendo a requests
#
# ## Primeira requisição

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %% [markdown]
# ## Explorando a biblioteca

# %%
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://api.github.com/events'

# %%
r.text
# Out:
# '[{"id":"38335436014","type":"IssueCommentEvent","actor":{"id":136622811,"login":"coderabbitai[bot]","display_login":"coderabbitai","gravatar_id":"","url":"https://api.github.com/users/coderabbitai[bot]","avatar_url":"https://avatars.githubusercontent.com/u/136622811?"},"repo":{"id":649247784,"name":"muhlba91/muehlbachler-xyz-global-dns","url":"https://api.github.com/repos/muhlba91/muehlbachler-xyz-global-dns"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/muhlba91/muehlbachler-xyz-global-dns/issues/245","repository_url":"https://api.github.com/repos/muhlba91/muehlbachler-xyz-global-dns","labels_url":"https://api.github.com/repos/muhlba91/muehlbachler-xyz-global-dns/issues/245/labels{/name}","comments_url":"https://api.github.com/repos/muhlba91/muehlbachler-xyz-global-dns/issues/245/comments","events_url":"https://api.github.com/repos/muhlba91/muehlbachler-xyz-global-dns/issues/245/events","html_url":"https://github.com/muhlba91/muehlbachler-xyz-global-dn
# ...

# %%
r.json()
# Out:
# [{'id': '38335436014',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 136622811,
#    'login': 'coderabbitai[bot]',
#    'display_login': 'coderabbitai',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/coderabbitai[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/136622811?'},
#   'repo': {'id': 649247784,
#    'name': 'muhlba91/muehlbachler-xyz-global-dns',
#    'url': 'https://api.github.com/repos/muhlba91/muehlbachler-xyz-global-dns'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/muhlba91/muehlbachler-xyz-global-dns/issues/245',
#     'repository_url': 'https://api.github.com/repos/muhlba91/muehlbachler-xyz-global-dns',
#     'labels_url': 'https://api.github.com/repos/muhlba91/muehlbachler-xyz-global-dns/issues/245/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/muhlba91/muehlbachler-xyz-global-dns/issues/245/comments',
# ...

# %%
r = requests.get('https://api.github.com/versions')
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# ['2022-11-28']

# %%
#especificando a versão do API
headers = {'X-gitHub-Api-Version': '2022-11-28'}

r = requests.get('https://api.github.com/events', headers=headers)

# %% [markdown]
# ### Desafiio Prático

# %%
response = requests.get('https://api.github.com/users/joseazev')
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '{"login":"joseazev","id":65934409,"node_id":"MDQ6VXNlcjY1OTM0NDA5","avatar_url":"https://avatars.githubusercontent.com/u/65934409?v=4","gravatar_id":"","url":"https://api.github.com/users/joseazev","html_url":"https://github.com/joseazev","followers_url":"https://api.github.com/users/joseazev/followers","following_url":"https://api.github.com/users/joseazev/following{/other_user}","gists_url":"https://api.github.com/users/joseazev/gists{/gist_id}","starred_url":"https://api.github.com/users/joseazev/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/joseazev/subscriptions","organizations_url":"https://api.github.com/users/joseazev/orgs","repos_url":"https://api.github.com/users/joseazev/repos","events_url":"https://api.github.com/users/joseazev/events{/privacy}","received_events_url":"https://api.github.com/users/joseazev/received_events","type":"User","site_admin":false,"name":"José Francisco Azevedo da Silva","company":null,"blog":"https://www.linkedin.com/i
# ...

# %%
response.url
# Out:
# 'https://api.github.com/users/joseazev'

# %%
dados = response.json()
dados
# Out:
# {'login': 'joseazev',
#  'id': 65934409,
#  'node_id': 'MDQ6VXNlcjY1OTM0NDA5',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/65934409?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/joseazev',
#  'html_url': 'https://github.com/joseazev',
#  'followers_url': 'https://api.github.com/users/joseazev/followers',
#  'following_url': 'https://api.github.com/users/joseazev/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/joseazev/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/joseazev/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/joseazev/subscriptions',
#  'organizations_url': 'https://api.github.com/users/joseazev/orgs',
#  'repos_url': 'https://api.github.com/users/joseazev/repos',
#  'events_url': 'https://api.github.com/users/joseazev/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/joseazev/received_events',
#  'type': 'User',
#  'site_admin': False,
# ...

# %%
nome = dados['name']
login = dados['login']
repositorios_pupblico = dados['public_repos']
data_criacao = dados['created_at']
print(f'Nome: {nome}')
print(f'Username: {login}')
print(f'Repositórios Publicos: {repositorios_pupblico}')
print(f'Criação do GitHub: {data_criacao}')
# Out:
# Nome: José Francisco Azevedo da Silva
# Username: joseazev
# Repositórios Publicos: 18
# Criação do GitHub: 2020-05-26T03:06:42Z

# %% [markdown]
# ## Extraindo dados

# %%
headers = {'X-gitHub-Api-Version': '2022-11-28'}

# %%
api_base_dados = 'https://api.github.com'
owner = 'amzn'
url = f'{api_base_dados}/users/{owner}/repos'

# %%
response =  requests.get(url,headers=headers)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# [{'id': 171339259,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#   'name': '.github',
#   'full_name': 'amzn/.github',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
# ...

# %%
len(response.json())
# Out:
# 30

# %%
access_token = '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'
headers = {'Authorization': 'Bearer ' + access_token,
           'X-gitHub-Api-Version': '2022-11-28'}

# %%
api_base_dados = 'https://api.github.com'
owner = 'amzn'
url = f'{api_base_dados}/users/{owner}/repos'
url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
repos_list = []
for page_num in range(1, 6):
    try:
        url_page = f'{url}?page={page_num}'
        response = requests.get(url_page, headers=headers)
        repos_list.append(response.json())
    except:
        repos_list.append(None)

# %%
repos_list
# Out:
# [[{'id': 171339259,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#    'name': '.github',
#    'full_name': 'amzn/.github',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
# ...

# %%
repos_list[0]
# Out:
# [{'id': 171339259,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#   'name': '.github',
#   'full_name': 'amzn/.github',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
# ...

# %%
len(repos_list[0])
# Out:
# 30

# %% [markdown]
# ## Nomes dos repositórios

# %%
repos_list[0][2]['name']
# Out:
# 'ads-pao-amznjs-gtm-template'

# %%
repos_name = []

for page in repos_list:
    for repo in page:
        repos_name.append(repo['name'])

# %%
repos_name[:10]
# Out:
# ['.github',
#  'ads-advanced-tools-docs',
#  'ads-pao-amznjs-gtm-template',
#  'alexa-coho',
#  'alexa-skills-kit-js',
#  'amazon-ads-advertiser-audience-normalization-sdk-py',
#  'amazon-advertising-api-php-sdk',
#  'amazon-codeguru-profiler-for-spark',
#  'amazon-frustration-free-setup-certification-tool',
#  'amazon-hub-counter-api-docs']

# %%
len(repos_name)
# Out:
# 150

# %% [markdown]
# ## Linguagens de repositórios

# %%
repos_list[1][1]
# Out:
# {'id': 33279165,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkzMzI3OTE2NQ==',
#  'name': 'amazon-pay-sdk-samples',
#  'full_name': 'amzn/amazon-pay-sdk-samples',
#  'private': False,
#  'owner': {'login': 'amzn',
#   'id': 8594673,
#   'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/amzn',
#   'html_url': 'https://github.com/amzn',
#   'followers_url': 'https://api.github.com/users/amzn/followers',
#   'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#   'organizations_url': 'https://api.github.com/users/amzn/orgs',
#   'repos_url': 'https://api.github.com/users/amzn/repos',
# ...

# %%
repos_list[1][1]['language']
# Out:
# 'PHP'

# %%
repos_langueges = []
for page in repos_list:
    for repo in page:
        repos_langueges.append(repo['language'])

# %%
repos_langueges[30]
# Out:
# 'Ruby'

# %%
len(repos_langueges)
# Out:
# 150

# %%
repos_langueges
# Out:
# [None,
#  None,
#  'Smarty',
#  'JavaScript',
#  None,
#  'Python',
#  'PHP',
#  'Java',
#  'Python',
#  'CSS',
#  'Java',
#  'Java',
#  'PowerShell',
#  'Java',
#  'C#',
#  'PHP',
#  'Ruby',
#  'JavaScript',
#  'Python',
#  'PHP',
#  'Python',
#  'Jupyter Notebook',
#  'C#',
#  'Java',
#  'JavaScript',
#  'PHP',
#  'C#',
#  'Java',
#  'PHP',
#  'Python',
#  'Ruby',
#  'PHP',
#  'Kotlin',
#  'PHP',
#  'Python',
#  'C',
#  None,
#  'Swift',
#  'Python',
#  'C++',
#  'Python',
#  'Go',
#  'C',
#  'Python',
#  'Python',
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  None,
#  'Java',
#  'Kotlin',
#  'Python',
#  'JavaScript',
#  'TypeScript',
#  'Python',
#  'TypeScript',
#  'JavaScript',
#  'TypeScript',
#  'Python',
#  None,
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  'Python',
#  'Java',
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  'Java',
#  'Objective-C',
#  'JavaScript',
#  'TypeScript',
#  'Java',
#  None,
#  'Python',
#  'Python',
#  'Python',
#  'Java',
# ...

# %%
import pandas as pd

# %%
dados_amzn = pd.DataFrame()
dados_amzn['repository_name'] = repos_name
dados_amzn['language'] = repos_langueges

# %%
dados_amzn
# Out:
#                  repository_name    language
# 0                        .github        None
# 1        ads-advanced-tools-docs        None
# 2    ads-pao-amznjs-gtm-template      Smarty
# 3                     alexa-coho  JavaScript
# 4            alexa-skills-kit-js        None
# ..                           ...         ...
# 145           workspace-resolver  JavaScript
# 146                       ws-vae      Python
# 147                         xfer      Python
# 148           zeek-plugin-bacnet        Zeek
# 149             zeek-plugin-enip        Zeek
#
# [150 rows x 2 columns]

# %%
dados_amzn.to_csv('amazon.csv',index=False)

# %% [markdown]
# ### Criando repositório com POST

# %%
api_base_url = 'https://api.github.com'
url = f'{api_base_url}/user/repos'

url
# Out:
# 'https://api.github.com/user/repos'

# %%
access_token = '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'
headers = {'Authorization': 'Bearer ' + access_token,
           'X-gitHub-Api-Version': '2022-11-28'}

# %%
data = {
    'name': 'linguagens-utilizadas',
    'description': 'Repositório com  as linguagens de programação da Amazon',
    'private': False
}

response = requests.post(url, json=data, headers=headers)
response.status_code
# Out:
# 422

# %%
response.json()
# Out:
# {'message': 'Repository creation failed.',
#  'errors': [{'resource': 'Repository',
#    'code': 'custom',
#    'field': 'name',
#    'message': 'name already exists on this account'}],
#  'documentation_url': 'https://docs.github.com/rest/repos/repos#create-a-repository-for-the-authenticated-user'}

# %% [markdown]
# ### Formato do Arquivo

# %%
import base64

# %%
with open('amazon.csv','rb') as file:
    file_content = file.read()

encoded_content = base64.b64encode(file_content)
encoded_content
# Out:
# b'...'

# %% [markdown]
# ## Upload de arquivo com PUT

# %%
api_base_url = 'https://api.github.com'
username = 'joseazev'
repo = 'linguagens-utilizadas'
path = 'amazon.csv'

url = f'{api_base_url}/repos/{username}/{repo}/contents/{path}'
url
# Out:
# 'https://api.github.com/repos/joseazev/linguagens-utilizadas/contents/amazon.csv'

# %%
encoded_content.decode('utf-8')
# Out:
# '...'

# %%
data = {
    'message': 'Adicionando um novo arquivo',
    'content': encoded_content.decode("utf-8")
}

# %%
response = requests.put(url, json=data, headers=headers)
response.status_code
# Out:
# 201
