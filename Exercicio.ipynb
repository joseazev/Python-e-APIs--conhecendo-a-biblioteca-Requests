# %%
import requests

# %%
access_token = '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'
headers = {'Authorization': 'Bearer ' + access_token,
           'X-gitHub-Api-Version': '2022-11-28'}

# %%
username = 'amzn'
url = f'https://api.github.com/users/{username}/followers'
followers_list = []
page = 1
teste = True
while teste:
    url_followers = f'{url}?page={page}'
    response1 = requests.get(url_followers)
    print(url_followers)
    if len(response1.json())==0:
        break
    followers_list.append(response1.json())
    page += 1

print(len(followers_list))
# Out:
# https://api.github.com/users/amzn/followers?page=1
# https://api.github.com/users/amzn/followers?page=2
# https://api.github.com/users/amzn/followers?page=3
# https://api.github.com/users/amzn/followers?page=4
# https://api.github.com/users/amzn/followers?page=5
# https://api.github.com/users/amzn/followers?page=6
# https://api.github.com/users/amzn/followers?page=7
# https://api.github.com/users/amzn/followers?page=8
# https://api.github.com/users/amzn/followers?page=9
# https://api.github.com/users/amzn/followers?page=10
# https://api.github.com/users/amzn/followers?page=11
# https://api.github.com/users/amzn/followers?page=12
# https://api.github.com/users/amzn/followers?page=13
# https://api.github.com/users/amzn/followers?page=14
# https://api.github.com/users/amzn/followers?page=15
# https://api.github.com/users/amzn/followers?page=16
# https://api.github.com/users/amzn/followers?page=17
# https://api.github.com/users/amzn/followers?page=18
# ...

# %%
followers_list[46][1]['login']
# Out:
# 'guiherme-git-tec'

# %%
followers_name = []
for page in followers_list:
    for user in page:
        followers_name.append(user['login'])

followers_name
# Out:
# ['tkersey',
#  'njonsson',
#  'bangpound',
#  'koconder',
#  'Rud5G',
#  'mlsj1',
#  'syug',
#  'esneko',
#  'neopunisher',
#  'jazzwang',
#  'begoon',
#  'fly51fly',
#  'fallenpegasus',
#  'fribeiro1',
#  'brase',
#  'chchrist',
#  'massimoselvi',
#  'ScottJWalter',
#  'adeelahmad',
#  'mindcrime',
#  'informaticadiaz',
#  'MarceloNascimento',
#  'dmsbilas',
#  'thimslugga',
#  'leecardona',
#  'shyuan',
#  'nara',
#  'openam',
#  'semsphy',
#  'srp19',
#  'DaemonCahill',
#  'Cambera',
#  'riyadparvez',
#  'nattfodd',
#  'mitaka',
#  'ZhangYunfang',
#  'temosy',
#  'threadstonesecure',
#  'manuelhunziker',
#  'ambagasdowa',
#  'pedro-lima',
#  'alexharvey',
#  'josh-fisher',
#  'kumarlokesh',
#  'subidit',
#  'pdevenraj',
#  'nerandell',
#  'raghuboosetty',
#  'tdmalone',
#  '34code',
#  'burib',
#  'whn09',
#  'bobbyearl',
#  'alishir',
#  'ahlfors',
#  'bsrz',
#  'mailmahee',
#  'mihkels',
#  'daefresh',
#  'dofstar',
#  'codee',
#  'LisaDelaney',
#  'EdZava',
#  'pmanolak',
# ...

# %%
import pandas as pd

# %%
dados_amzn = pd.DataFrame()
dados_amzn['users'] = followers_name
dados_amzn
# Out:
#             users
# 0         tkersey
# 1        njonsson
# 2       bangpound
# 3        koconder
# 4           Rud5G
# ...           ...
# 1405     iirachet
# 1406  chuqiang188
# 1407  Michael-MSL
# 1408  SkyeCai0608
# 1409     GeekAmir
#
# [1410 rows x 1 columns]

# %%
dados_amzn.to_csv('seguidores.csv', index=False)

# %% [markdown]
# ## Criando um repositório

# %%
url_api_repos = 'https://api.github.com'
url = f'{url_api_repos}/user/repos'
url
# Out:
# 'https://api.github.com/user/repos'

# %%
token = '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'
headers = {'Authorization': 'Bearer ' + token,
           'X-gitHub-Api-Version': '2022-11-28'}

# %%
data = {
    'name': 'seguidores-repositorio',
    'description': 'Lista de seguidores dos repositórios da Amazon',
    'private': False
}

response = requests.post(url, json=data, headers=headers)
response.status_code
# Out:
# 201

# %%
response.json()
# Out:
# {'id': 800214880,
#  'node_id': 'R_kgDOL7JPYA',
#  'name': 'seguidores-repositorio',
#  'full_name': 'joseazev/seguidores-repositorio',
#  'private': False,
#  'owner': {'login': 'joseazev',
#   'id': 65934409,
#   'node_id': 'MDQ6VXNlcjY1OTM0NDA5',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/65934409?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/joseazev',
#   'html_url': 'https://github.com/joseazev',
#   'followers_url': 'https://api.github.com/users/joseazev/followers',
#   'following_url': 'https://api.github.com/users/joseazev/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/joseazev/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/joseazev/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/joseazev/subscriptions',
#   'organizations_url': 'https://api.github.com/users/joseazev/orgs',
#   'repos_url': 'https://api.github.com/users/joseazev/repos',
# ...

# %% [markdown]
# ## Preparando o arquivo

# %%
import base64

# %%
with open('seguidores.csv','rb') as file:
    file_content = file.read()

encode_content = base64.b64encode(file_content)

# %%
url_api_put = 'https://api.github.com'
username = 'joseazev'
repo = 'seguidores-repositorio'
path = 'seguidores.csv'

url = f'{url_api_put}/repos/{username}/{repo}/contents/{path}'
url
# Out:
# 'https://api.github.com/repos/joseazev/seguidores-repositorio/contents/seguidores.csv'

# %%
data = {
    'message': 'Novo Arquivo enviado',
    'content': encode_content.decode('utf-8')
}

response = requests.put(url, json=data, headers=headers)
response.status_code
# Out:
# 201

# %%
response.json()
# Out:
# {'content': {'name': 'seguidores.csv',
#   'path': 'seguidores.csv',
#   'sha': '0f5a2834d4744cc4c99d8a47894eb70a8093af72',
#   'size': 15993,
#   'url': 'https://api.github.com/repos/joseazev/seguidores-repositorio/contents/seguidores.csv?ref=main',
#   'html_url': 'https://github.com/joseazev/seguidores-repositorio/blob/main/seguidores.csv',
#   'git_url': 'https://api.github.com/repos/joseazev/seguidores-repositorio/git/blobs/0f5a2834d4744cc4c99d8a47894eb70a8093af72',
#   'download_url': 'https://raw.githubusercontent.com/joseazev/seguidores-repositorio/main/seguidores.csv',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/joseazev/seguidores-repositorio/contents/seguidores.csv?ref=main',
#    'git': 'https://api.github.com/repos/joseazev/seguidores-repositorio/git/blobs/0f5a2834d4744cc4c99d8a47894eb70a8093af72',
#    'html': 'https://github.com/joseazev/seguidores-repositorio/blob/main/seguidores.csv'}},
# ...
